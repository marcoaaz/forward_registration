# %%
'''
'classifyFolder_wVectors_v4.ipynb' script

Script for generating classifying feature vectors for each image patch pre-saved in a folder with 'extractingBB_labelledWSI_v3.py'.

Documentation:
This code mostly follows "miso.inference.classify import classify_folder as miso_classify_folder."
#for model_vector
https://github.com/microfossil/particle-classification/blob/master/miso/deploy/saving.py  
#for KNN
https://github.com/microfossil/particle-classification/blob/master/miso/inference/classify.py
#for generating mislabeled folder and TSNE with feature vectors
https://github.com/microfossil/particle-classification/blob/master/miso/training/trainer.py
#for extracting vector from compiled tf Keras model
https://github.com/microfossil/particle-classification/blob/master/miso/models/factory.py 
#for saving mislabeled images (uses feature vectors)
https://github.com/microfossil/particle-classification/blob/master/miso/stats/mislabelling.py

Created: 31-Jan-2025, Marco Acevedo
Updated: 4-Mar-2024, 7-Mar, M.A.

Notes:
Working environment: .conda (Python 3.9.20)
The requirements are listed in 'requirements.txt' ('requirements_base.txt' was for my whole operative system)

To activate conda environment (Command Prompt only):
check that it exist:        conda info --envs
activate:     conda activate "e:\Feb-March_2024_zircon imaging\ParticleTrieur_trial_cl_zircon_annotated\.conda"

'''
# Out:
# "\n'classifyFolder_wVectors_v4.ipynb' script\n\nScript following from miso.inference.classify import classify_folder as miso_classify_folder.\nIt also allows generating the feature vectors for each image.\n\nDocumentation:\n#for model_vector\nhttps://github.com/microfossil/particle-classification/blob/master/miso/deploy/saving.py  \n#for KNN\nhttps://github.com/microfossil/particle-classification/blob/master/miso/inference/classify.py\n#for generating mislabeled folder and TSNE with feature vectors\nhttps://github.com/microfossil/particle-classification/blob/master/miso/training/trainer.py\n#for extracting vector from compiled tf Keras model\nhttps://github.com/microfossil/particle-classification/blob/master/miso/models/factory.py \n#for saving mislabeled images (uses feature vectors)\nhttps://github.com/microfossil/particle-classification/blob/master/miso/stats/mislabelling.py\n\nCreated: 31-Jan-2025, M.A.\nUpdated: 4-Mar-2024, 7-Mar, M.A.\n\n"

# %%
import os
import random
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np
import onnx
import pandas as pd
import skimage.io
from PIL import Image
from tqdm import tqdm

from miso.models.factory import *
from miso.data.image_utils import load_image
from miso.deploy.model_info import ModelInfo
from miso.deploy.saving import load_frozen_model_tf2, load_from_xml, load_onnx_from_xml
import tensorflow as tf

import json
from munch import DefaultMunch
from sklearn.neighbors import KNeighborsClassifier
from sklearn.utils.extmath import weighted_mode
from sklearn.preprocessing import normalize

import lxml.etree as ET

#Helper functions 

def get_image_paths_and_samples(base_path, sample_name="unknown"):
    #Note 1: remaining issue with filename sorting (not numerical), probably needs grain number with leading zeros
    #Note 2: the input patches might not begin at 1 (depends on QuPath irregular segmentation) but 2 (which fixes Note 1 issue)

    base_path = Path(base_path)
    image_paths = []
    samples = []
    for subdir in base_path.iterdir():
        if subdir.is_dir():
            for file in subdir.rglob('*'):
                if file.suffix.lower() in ('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.tiff', '.tif'):
                    image_paths.append(str(file))
                    samples.append(subdir.name)
        else:
            file = subdir
            if file.suffix.lower() in ('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.tiff', '.tif'):
                image_paths.append(str(file))
                samples.append(sample_name)
    return image_paths, samples

# Image loading functions
def load_and_preprocess_image(image_path):
    def _load_image(image_path):
        image_path = image_path.numpy().decode('utf-8')
        image = load_image(image_path, img_size, img_type)
        image = tf.convert_to_tensor(image, dtype=tf.float32)
        return image
    image = tf.py_function(_load_image, [image_path], tf.float32)
    image.set_shape(img_size)
    return image

# %% [markdown]
# User input

# %%
#images_path = r'D:\Charlotte_spot proj\qupath_segmentation\CL_7-Apr-25\CL'
#images_path = r'D:\Justin Freeman collab\25-mar-2025_Apreo2\CA24MR-1_Redo_stitched and unstitched tiles\montages_final\segmentation\CL_28-Mar-25_row1\row1_stack_CL_greyscale'
images_path = r'C:\Users\acevedoz\OneDrive - Queensland University of Technology\Desktop\Ruby Creek_db_imagery\GA6141_Cross_Mole granite\registered\segmentation\RL_GA6141 200701550_1\CL_GA6141 200701550'

model_info_path = r'E:\Feb-March_2024_zircon imaging\ParticleTrieur_trial_cl_zircon_annotated\trained model_8-Oct-24\ResNet50_cyclic_test7_20241008-135142\model_tf2\network_info.xml'
sample_name = "CA24MR-1_first"
num_neighbours = 11 # K-NN search, default= 11

#images
c = os.path.basename(images_path)
images_path_dir = os.path.join(images_path, 'PT_patches')
output_path = os.path.join(images_path_dir, c + '_vector.csv') #feature vectors
output_path2 = os.path.join(images_path_dir, c + '_vector-knn.csv') #knn pythonic idx

#model
batch_size = 32 #32
unsure_threshold = 0.0
a = os.path.dirname(model_info_path)
b = os.path.dirname(a)    
file_tp = os.path.join(b, r"training_parameters.json")

# %% [markdown]
# Load models

# %%
#follows miso.inference.classify
model, img_size, img_type, labels = load_from_xml(model_info_path) 
#frozen tf model ('WrappedFunction' object)

##pre-check the right layer is chosen
#list_layers = model.graph.get_operations()
#test = list_layers[-14:] #-12:
#test1 = [op.values() for op in test]
#print("\n".join(map(str, test1)))

#follows miso.deploy.saving
filename = model_info_path
project = ET.parse(filename).getroot()
protobuf = project.find('protobuf').text
print(f"Loading model from {filename}")
print("- protobuf: " + protobuf)

full_protobuf_path = os.path.join(os.path.dirname(filename), protobuf)
list_xml = project.find('inputs')
for i, entry_xml in enumerate(list_xml.iter('input')):
    if i == 0:
        input_name = entry_xml.find('operation').text + ":0"

vector_model = load_frozen_model_tf2(full_protobuf_path, input_name, 'model_2/dense/Relu:0')
# Out:
# Loading model from E:\Feb-March_2024_zircon imaging\ParticleTrieur_trial_cl_zircon_annotated\trained model_8-Oct-24\ResNet50_cyclic_test7_20241008-135142\model_tf2\network_info.xml
# - protobuf: frozen_model.pb
# - labels:
#   - blank-blank
#   - blank-oscillatory
#   - metamict
#   - oscillatory-oscillatory
#   - oscillatory-sector op
#   - sector-oscillatory
#   - sector-oscillatory sector op
#   - sector-sector
#   - stripy-stripy
#   - wavy-wavy
# - input: x:0
#   - height: 224
#   - width: 224
#   - channels: 3
# - output: Identity:0
# Loading model from E:\Feb-March_2024_zircon imaging\ParticleTrieur_trial_cl_zircon_annotated\trained model_8-Oct-24\ResNet50_cyclic_test7_20241008-135142\model_tf2\network_info.xml
# - protobuf: frozen_model.pb

# %% [markdown]
# Classify folder: producing feature vectors

# %%
#follows particle-classification/miso/inference/classify.py > classify_folder

# Create a dataset of image paths
image_paths, sample_names = get_image_paths_and_samples(images_path, sample_name)

image_dataset = tf.data.Dataset.from_tensor_slices(image_paths)
image_dataset = image_dataset.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
image_dataset = image_dataset.batch(batch_size)

# Run predictions
vector_list = []
predictions = []
idxs = []
cls = []
scores = []
for batch in tqdm(image_dataset):
   
    #Predict class
    preds = model(batch).numpy() #frozen model

    #Calculate feature vector
    batch_vectors = vector_model(batch).numpy() #not fine-tuned (issue)    

    batch_idxs = np.argmax(preds, axis=1)
    batch_labels = [labels[idx] for idx in batch_idxs]
    batch_scores = np.max(preds, axis=1)
    
    #Append
    vector_list.extend(batch_vectors)
    predictions.extend(preds)
    idxs.extend(batch_idxs)
    cls.extend(batch_labels)
    scores.extend(batch_scores)

idxs = [idx if score > unsure_threshold else -1 for idx, score in zip(idxs, scores)]
cls = [cls if score > unsure_threshold else "unsure" for cls, score in zip(cls, scores)]

df = pd.DataFrame({
    "filename": image_paths,
    "short_filename": [Path(f).relative_to(images_path) for f in image_paths],
    "sample": sample_names,
    "class_index": idxs,
    "class": cls,
    "score": scores
})

#follows particle-classification.miso.stats.mislabelling.py > find_and_save_mislabelled
vector_array = np.array(vector_list)
vectors_n = normalize(vector_array, axis=1) #default=’l2’ Euclidean

#Generating new table
new_df = pd.DataFrame(vectors_n, 
                      columns=['vector_'+str(i) for i in range(vectors_n.shape[1])])
df2 = pd.concat([df, new_df], axis=1)


df2.to_csv(output_path, index=False)
# Out:
# 100%|██████████| 8/8 [00:12<00:00,  1.55s/it]

# %% [markdown]
# K-Nearest Neighbors using vectors (for sorting)

# %%
# cls_labels = df2["class"].to_list() #label names
cls = df2["class_index"].to_numpy() #label numbers
image_names = df2["filename"].to_list()

# Fit k-Nearest neighbours
neigh = KNeighborsClassifier(n_neighbors=num_neighbours + 1, algorithm='brute')
neigh.fit(vectors_n, cls)

# Find k nearest vectors
num_neighbours_sort = len(cls)
knn = neigh.kneighbors(vectors_n, n_neighbors=num_neighbours_sort)
distance = knn[0][:, 1:] #n_images x num_neighbours - 1 (ascending order)
idx_knn = knn[1][:, 1:] #pythonic idx (same order as input dataframe; warning: filename sorting is not numerical)
# The first will be the same vector as passed in so ignore it

# Get the predicted class from knn (ignoring the same vector)
knn_cls = cls[idx_knn]
wm = weighted_mode(knn_cls, np.max(distance) - distance, axis=1)
pred_cls = wm[0].astype(int).flatten() #label number (from Array of modal values)
pred_w = wm[1].flatten()  #Array of weighted counts for each mode. default=not flatten

#Generating output table 
dict_temp = {'pred_cls': pred_cls, 
             'pred_w': pred_w}
new_df2 = pd.DataFrame(data= dict_temp)

new_df3 = pd.DataFrame(idx_knn, 
                      columns=['idx_knn_'+str(i) for i in range(idx_knn.shape[1])])

df3 = pd.concat([df2, new_df2, new_df3], axis=1)
df3.to_csv(output_path2, index=False)

output_path2 #to search feature vectors with 'prototype_two_v9.m' script
# Out:
# 'C:\\Users\\acevedoz\\OneDrive - Queensland University of Technology\\Desktop\\Ruby Creek_db_imagery\\GA6141_Cross_Mole granite\\registered\\segmentation\\RL_GA6141 200701550_1\\CL_GA6141 200701550\\PT_patches\\CL_GA6141 200701550_vector-knn.csv'

# %%
image_paths
# Out:
# ['D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_100_[x=5046,y=3006,w=582,h=356].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_101_[x=53852,y=3016,w=276,h=436].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_102_[x=39024,y=3028,w=796,h=478].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_103_[x=53300,y=3054,w=388,h=352].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_104_[x=9514,y=3056,w=352,h=314].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_105_[x=23894,y=3060,w=666,h=318].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_106_[x=50960,y=3064,w=232,h=422].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_107_[x=57046,y=3066,w=426,h=254].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_108_[x=15584,y=3078,w=508,h=552].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_109_[x=10794,y=3086,w=162,h=708].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_10_[x=63258,y=1684,w=298,h=216].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_110_[x=33744,y=3096,w=328,h=402].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_111_[x=34984,y=3102,w=446,h=258].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_112_[x=23228,y=3104,w=244,h=440].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_113_[x=27082,y=3104,w=292,h=466].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_114_[x=31602,y=3114,w=332,h=388].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_115_[x=36512,y=3146,w=454,h=558].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_116_[x=23612,y=3152,w=272,h=494].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_117_[x=7076,y=3154,w=208,h=256].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_118_[x=17284,y=3154,w=400,h=370].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_119_[x=28762,y=3160,w=270,h=358].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_11_[x=64440,y=1704,w=560,h=376].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_120_[x=59974,y=3164,w=528,h=400].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_121_[x=16856,y=3168,w=330,h=580].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_122_[x=27592,y=3168,w=656,h=516].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_123_[x=1998,y=3170,w=372,h=464].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_124_[x=51996,y=3216,w=522,h=300].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_125_[x=7688,y=3220,w=482,h=216].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_126_[x=49098,y=3224,w=372,h=536].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_127_[x=41406,y=3236,w=352,h=350].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_128_[x=31346,y=3248,w=378,h=442].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_129_[x=62946,y=3252,w=618,h=446].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_12_[x=10040,y=1714,w=414,h=574].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_130_[x=18606,y=3258,w=490,h=520].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_131_[x=10582,y=3260,w=204,h=446].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_132_[x=43978,y=3262,w=418,h=504].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_133_[x=8234,y=3266,w=320,h=376].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_134_[x=40282,y=3268,w=274,h=330].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_135_[x=47900,y=3268,w=300,h=674].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_136_[x=8596,y=3278,w=468,h=262].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_137_[x=55180,y=3278,w=468,h=322].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_138_[x=12262,y=3284,w=468,h=374].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_139_[x=49834,y=3284,w=502,h=224].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_13_[x=53164,y=1762,w=462,h=228].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_140_[x=64626,y=3292,w=414,h=284].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_141_[x=48788,y=3294,w=348,h=286].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_142_[x=6072,y=3296,w=208,h=298].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null
jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_47_[x=7074,y=2472,w=184,h=310].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_48_[x=55982,y=2500,w=402,h=398].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_49_[x=9436,y=2502,w=466,h=498].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_4_[x=61768,y=1198,w=418,h=358].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_50_[x=58642,y=2514,w=216,h=486].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_51_[x=5246,y=2536,w=280,h=392].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_52_[x=64880,y=2548,w=376,h=272].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_53_[x=35036,y=2552,w=574,h=280].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_54_[x=6250,y=2554,w=344,h=288].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_55_[x=4462,y=2558,w=248,h=292].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_56_[x=47642,y=2568,w=426,h=426].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_57_[x=52904,y=2574,w=270,h=404].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_58_[x=12850,y=2584,w=360,h=308].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_59_[x=59062,y=2590,w=522,h=472].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_5_[x=56156,y=1296,w=344,h=592].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_60_[x=3118,y=2592,w=304,h=496].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_61_[x=60706,y=2594,w=504,h=232].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_62_[x=40718,y=2602,w=350,h=316].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_63_[x=42284,y=2608,w=398,h=220].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_64_[x=42008,y=2614,w=184,h=206].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_65_[x=65662,y=2616,w=344,h=352].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_66_[x=7990,y=2630,w=392,h=362].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_67_[x=46504,y=2658,w=402,h=286].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_68_[x=50058,y=2672,w=238,h=266].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_69_[x=3712,y=2674,w=460,h=414].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_6_[x=37782,y=1568,w=108,h=104].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_70_[x=54986,y=2694,w=266,h=488].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_71_[x=17978,y=2696,w=440,h=412].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_72_[x=63422,y=2708,w=758,h=450].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_73_[x=44972,y=2746,w=548,h=190].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_74_[x=64052,y=2752,w=488,h=638].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_75_[x=65152,y=2764,w=326,h=494].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_76_[x=52270,y=2790,w=344,h=264].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_77_[x=19438,y=2800,w=586,h=458].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_78_[x=15320,y=2824,w=536,h=286].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_79_[x=7304,y=2836,w=282,h=320].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_7_[x=37660,y=1598,w=758,h=752].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_80_[x=21886,y=2836,w=400,h=254].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_81_[x=22170,y=2842,w=236,h=204].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_82_[x=10396,y=2846,w=484,h=340].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_83_[x=61470,y=2852,w=286,h=374].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_84_[x=29740,y=2856,w=596,h=602].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_85_[x=8798,y=2872,w=224,h=386].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_86_[x=14638,y=2890,w=338,h=510].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_87_[x=37270,y=2898,w=350,h=460].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_88_[x=60646,y=2916,w=330,h=558].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_89_[x=6718,y=2920,w=256,h=438].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_8_[x=58342,y=1672,w=504,h=516].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_90_[x=3850,y=2948,w=1156,h=676].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_91_[x=45436,y=2954,w=532,h=420].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_92_[x=13254,y=2962,w=584,h=252].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_93_[x=48534,y=2964,w=192,h=706].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_94_[x=40138,y=2968,w=308,h=280].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_95_[x=58140,y=2970,w=302,h=496].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_96_[x=12864,y=2974,w=316,h=342].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_97_[x=11416,y=2992,w=552,h=442].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_98_[x=50246,y=2992,w=350,h=244].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_99_[x=46004,y=3004,w=542,h=284].jpg',
#  'D:\\Justin Freeman collab\\25-mar-2025_Apreo2\\CA24MR-1_Redo_stitched and unstitched tiles\\montages_final\\segmentation\\CL_28-Mar-25_row1\\row1_stack_CL_greyscale\\PT_patches\\row1_stack-0001_null_9_[x=63640,y=1676,w=246,h=284].jpg']
